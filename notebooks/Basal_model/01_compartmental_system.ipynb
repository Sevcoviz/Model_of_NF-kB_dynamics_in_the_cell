# %% [markdown]
# # Compartmental system

# %%
from simulacia import SimulateCompartmentalSystem
from vizualizacia import plot_compartmental_dynamics, plot_nfkb_compartmental

# %%
simulator = SimulateCompartmentalSystem(t_max=100000.0) # You can adjust t_max as needed
t, K, N_C, N_N, I_C, I_N, NI_C, NI_N, G, R = simulator.run_solver()

plot_compartmental_dynamics(t, K, N_C, N_N, I_C, I_N, NI_C, NI_N, R, G)

# %%
simulator = SimulateCompartmentalSystem(t_max=10000.0) # You can adjust t_max as needed
t, K, N_C, N_N, I_C, I_N, NI_C, NI_N, G, R = simulator.run()
plot_nfkb_compartmental(t, K, N_C, N_N, I_C, I_N, NI_C, NI_N, G, R)
# Out:
# c:\Users\sevco\Documents\modelovanie\New\Model_of_NF-kB_dynamics_in_the_cell\notebooks\vizualizacia.py:126: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
